# %%
import pandas as pd
import numpy as np

# %%
battles = pd.read_csv(
    "revolutionary_war.csv", 
    parse_dates=["Start Date"],
    usecols=["Start Date"],
).squeeze()

battles
# Out:
# 0     1774-09-01
# 1     1774-12-14
# 2     1775-04-19
# 3     1775-04-19
# 4     1775-04-20
#          ...
# 227   1782-09-11
# 228   1782-09-13
# 229   1782-10-18
# 230   1782-12-06
# 231   1783-01-22
# Name: Start Date, Length: 232, dtype: datetime64[ns]

# %%
import datetime as dt

today = dt.datetime(2020, 12, 26)
today.strftime("%A")
# Out:
# 'Saturday'

# %%
(
    battles
    .dropna()
    .apply(func=lambda date_obj: date_obj.strftime("%A"))
    .value_counts(ascending=False)
)
# Out:
# Start Date
# Saturday     39
# Friday       39
# Wednesday    32
# Thursday     31
# Sunday       31
# Tuesday      29
# Monday       27
# Name: count, dtype: int64
