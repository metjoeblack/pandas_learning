# %%
import pandas as pd
import numpy as np

# %%
inspections = pd.read_csv("datasets/chicago_food_inspections.csv")

inspections.head()
# Out:
#                           Name             Risk
# 0   MARRIOT MARQUIS CHICAGO       Risk 1 (High)
# 1                  JETS PIZZA   Risk 2 (Medium)
# 2                   ROOM 1520      Risk 3 (Low)
# 3    MARRIOT MARQUIS CHICAGO      Risk 1 (High)
# 4                CHARTWELLS       Risk 1 (High)

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    153810 non-null  object
#  1   Risk    153744 non-null  object
# dtypes: object(2)
# memory usage: 2.3+ MB

# %%
inspections.head()
# Out:
#                           Name             Risk
# 0   MARRIOT MARQUIS CHICAGO       Risk 1 (High)
# 1                  JETS PIZZA   Risk 2 (Medium)
# 2                   ROOM 1520      Risk 3 (Low)
# 3    MARRIOT MARQUIS CHICAGO      Risk 1 (High)
# 4                CHARTWELLS       Risk 1 (High)

# %%
inspections["Name"].head().values
# Out:
# array([' MARRIOT MARQUIS CHICAGO   ', ' JETS PIZZA ', '   ROOM 1520 ',
#        '  MARRIOT MARQUIS CHICAGO  ', ' CHARTWELLS   '], dtype=object)

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    153810 non-null  object
#  1   Risk    153744 non-null  object
# dtypes: object(2)
# memory usage: 2.3+ MB

# %%
inspections["Name"].head()
# Out:
# 0     MARRIOT MARQUIS CHICAGO
# 1                    JETS PIZZA
# 2                     ROOM 1520
# 3      MARRIOT MARQUIS CHICAGO
# 4                  CHARTWELLS
# Name: Name, dtype: object

# %%
inspections["Name"].str

# %%
inspections["Name"].str.lstrip().head().values
# Out:
# array(['MARRIOT MARQUIS CHICAGO   ', 'JETS PIZZA ', 'ROOM 1520 ',
#        'MARRIOT MARQUIS CHICAGO  ', 'CHARTWELLS   '], dtype=object)

# %%
inspections["Name"].str.rstrip().head().values
# Out:
# array([' MARRIOT MARQUIS CHICAGO', ' JETS PIZZA', '   ROOM 1520',
#        '  MARRIOT MARQUIS CHICAGO', ' CHARTWELLS'], dtype=object)

# %%
inspections["Name"].str.strip().head().values
# Out:
# array(['MARRIOT MARQUIS CHICAGO', 'JETS PIZZA', 'ROOM 1520',
#        'MARRIOT MARQUIS CHICAGO', 'CHARTWELLS'], dtype=object)

# %%
def wrangle_whitespace(df_obj):
    for column in df_obj.columns:
        df_obj[column] = df_obj[column].str.strip()

wrangle_whitespace(inspections)

# %%
inspections["Name"].str.strip().head().values
# Out:
# array(['MARRIOT MARQUIS CHICAGO', 'JETS PIZZA', 'ROOM 1520',
#        'MARRIOT MARQUIS CHICAGO', 'CHARTWELLS'], dtype=object)

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    153810 non-null  object
#  1   Risk    153744 non-null  object
# dtypes: object(2)
# memory usage: 2.3+ MB

# %%
inspections["Name"].head()
# Out:
# 0    MARRIOT MARQUIS CHICAGO
# 1                 JETS PIZZA
# 2                  ROOM 1520
# 3    MARRIOT MARQUIS CHICAGO
# 4                 CHARTWELLS
# Name: Name, dtype: object

# %%
inspections["Name"].str.lower().head()
# Out:
# 0    marriot marquis chicago
# 1                 jets pizza
# 2                  room 1520
# 3    marriot marquis chicago
# 4                 chartwells
# Name: Name, dtype: object

# %%
inspections.head()
# Out:
#                       Name             Risk
# 0  MARRIOT MARQUIS CHICAGO    Risk 1 (High)
# 1               JETS PIZZA  Risk 2 (Medium)
# 2                ROOM 1520     Risk 3 (Low)
# 3  MARRIOT MARQUIS CHICAGO    Risk 1 (High)
# 4               CHARTWELLS    Risk 1 (High)

# %%
inspections["Name"] = inspections["Name"].str.title()

# %%
inspections.head()
# Out:
#                       Name             Risk
# 0  Marriot Marquis Chicago    Risk 1 (High)
# 1               Jets Pizza  Risk 2 (Medium)
# 2                Room 1520     Risk 3 (Low)
# 3  Marriot Marquis Chicago    Risk 1 (High)
# 4               Chartwells    Risk 1 (High)

# %%
inspections["Risk"] = inspections["Risk"].replace(
    to_replace="All", 
    value="Risk 4 (Extreme)",
)

# %%
inspections["Risk"].unique()
# Out:
# array(['Risk 1 (High)', 'Risk 2 (Medium)', 'Risk 3 (Low)',
#        'Risk 4 (Extreme)', nan], dtype=object)

# %%
inspections["Risk"] = inspections["Risk"].astype(dtype="category")

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153810 entries, 0 to 153809
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    153810 non-null  object
#  1   Risk    153744 non-null  category
# dtypes: category(1), object(1)
# memory usage: 1.3+ MB

# %%
len(inspections)
# Out:
# 153810

# %%
inspections = inspections.dropna(subset=["Risk"], how="any")

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153744 entries, 0 to 153809
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    153744 non-null  object
#  1   Risk    153744 non-null  category
# dtypes: category(1), object(1)
# memory usage: 2.5+ MB

# %%
inspections["Risk"].str.slice(5, 6).head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    1
# Name: Risk, dtype: object

# %%
inspections["Risk"].str[5:6].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    1
# Name: Risk, dtype: object

# %%
inspections["Risk"].str.slice(8, -1).head()
# Out:
# 0      High
# 1    Medium
# 2       Low
# 3      High
# 4      High
# Name: Risk, dtype: object

# %%
inspections["Risk"].str[8:-1].head()
# Out:
# 0      High
# 1    Medium
# 2       Low
# 3      High
# 4      High
# Name: Risk, dtype: object

# %%
inspections["Risk"].str.slice(8).str.replace(')', '').head()
# Out:
# 0      High
# 1    Medium
# 2       Low
# 3      High
# 4      High
# Name: Risk, dtype: object

# %%
has_pizza = inspections["Name"].str.lower().str.contains("pizza")

has_pizza.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
inspections[has_pizza].head()
# Out:
#                              Name             Risk
# 1                      Jets Pizza  Risk 2 (Medium)
# 19  Nancy'S Home Of Stuffed Pizza    Risk 1 (High)
# 27     Nary'S Grill & Pizza ,Inc.    Risk 1 (High)
# 29            Narys Grill & Pizza    Risk 1 (High)
# 68                  Colutas Pizza    Risk 1 (High)

# %%
starts_with_tacos = inspections["Name"].str.lower().str.startswith("tacos")

# ends_with_tacos = inspections["Name"].str.lower().str.endswith("tacos")

starts_with_tacos.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
inspections[starts_with_tacos].head()
# Out:
#                      Name           Risk
# 69           Tacos Nietos  Risk 1 (High)
# 556   Tacos El Tio 2 Inc.  Risk 1 (High)
# 675      Tacos Don Gabino  Risk 1 (High)
# 958   Tacos El Tio 2 Inc.  Risk 1 (High)
# 1036  Tacos El Tio 2 Inc.  Risk 1 (High)

# %%
customers = pd.read_csv("datasets/customers.csv")

customers
# Out:
#                      Name                                            Address
# 0           Frank Manning  6461 Quinn Groves, East Matthew, New Hampshire...
# 1       Elizabeth Johnson  1360 Tracey Ports Apt. 419, Kyleport, Vermont,...
# 2         Donald Stephens  19120 Fleming Manors, Prestonstad, Montana, 23495
# 3     Michael Vincent III       441 Olivia Creek, Jimmymouth, Georgia, 82991
# 4          Jasmine Zamora  4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...
# ...                   ...                                                ...
# 9956        Dana Browning  762 Andrew Views Apt. 254, North Paul, New Mex...
# 9957      Amanda Anderson  44188 Day Crest Apt. 901, Lake Marcia, Maine, ...
# 9958           Eric Davis  73015 Michelle Squares, Watsonville, West Virg...
# 9959     Taylor Hernandez       129 Keith Greens, Haleyfurt, Oklahoma, 98916
# 9960     Sherry Nicholson   355 Griffin Valley, Davidtown, New Mexico, 17581
#
# [9961 rows x 2 columns]

# %%
customers["Name"].head().values
# Out:
# array(['Frank Manning', 'Elizabeth Johnson', 'Donald Stephens',
#        'Michael Vincent III', 'Jasmine Zamora'], dtype=object)

# %%
customers["Address"].head(10).values
# Out:
# array(['6461 Quinn Groves, East Matthew, New Hampshire, 16656',
#        '1360 Tracey Ports Apt. 419, Kyleport, Vermont, 31924',
#        '19120 Fleming Manors, Prestonstad, Montana, 23495',
#        '441 Olivia Creek, Jimmymouth, Georgia, 82991',
#        '4246 Chelsey Ford Apt. 310, Karamouth, Utah, 76252',
#        '79736 Harris Plains, Lake Jennachester, Kentucky, 22299',
#        '89808 Brown Plains, Fordhaven, Maryland, 16818',
#        '778 James Common Suite 546, North Christine, Utah, 68320',
#        '9566 Spencer Drive Apt. 219, New Alexandriamouth, Delaware, 56917',
#        '6587 Victoria Wells, North Lisa, Georgia, 42954'], dtype=object)

# %%
customers["Name"].str.len().head()
# Out:
# 0    13
# 1    17
# 2    15
# 3    19
# 4    14
# Name: Name, dtype: int64

# %%
customers["Name"].str.split(pat=" ", n=1).head()
# Out:
# 0          [Frank, Manning]
# 1      [Elizabeth, Johnson]
# 2        [Donald, Stephens]
# 3    [Michael, Vincent III]
# 4         [Jasmine, Zamora]
# Name: Name, dtype: object

# %%
customers["Name"].str.split(pat=" ", n=1).str.len().head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Name, dtype: int64

# %%
customers["Name"].str.split(pat=" ", n=1).str.get(0).head()
# Out:
# 0        Frank
# 1    Elizabeth
# 2       Donald
# 3      Michael
# 4      Jasmine
# Name: Name, dtype: object

# %%
customers["Name"].str.split(pat=" ", n=1).str.get(1).head()  # str.get(-1)
# Out:
# 0        Manning
# 1        Johnson
# 2       Stephens
# 3    Vincent III
# 4         Zamora
# Name: Name, dtype: object

# %%
customers["Name"].str.split(pat=" ", n=1, expand=True).head()
# Out:
#            0            1
# 0      Frank      Manning
# 1  Elizabeth      Johnson
# 2     Donald     Stephens
# 3    Michael  Vincent III
# 4    Jasmine       Zamora

# %%
customers[["First Name", "Last Name"]] = customers["Name"].str.split(pat=" ", n=1, expand=True)

# %%
customers
# Out:
#                      Name                                            Address  \
# 0           Frank Manning  6461 Quinn Groves, East Matthew, New Hampshire...
# 1       Elizabeth Johnson  1360 Tracey Ports Apt. 419, Kyleport, Vermont,...
# 2         Donald Stephens  19120 Fleming Manors, Prestonstad, Montana, 23495
# 3     Michael Vincent III       441 Olivia Creek, Jimmymouth, Georgia, 82991
# 4          Jasmine Zamora  4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...
# ...                   ...                                                ...
# 9956        Dana Browning  762 Andrew Views Apt. 254, North Paul, New Mex...
# 9957      Amanda Anderson  44188 Day Crest Apt. 901, Lake Marcia, Maine, ...
# 9958           Eric Davis  73015 Michelle Squares, Watsonville, West Virg...
# 9959     Taylor Hernandez       129 Keith Greens, Haleyfurt, Oklahoma, 98916
# 9960     Sherry Nicholson   355 Griffin Valley, Davidtown, New Mexico, 17581
#
#      First Name    Last Name
# ...

# %%
customers = customers.drop(labels=["Name"], axis="columns")

# %%
customers
# Out:
#                                                 Address First Name  \
# 0     6461 Quinn Groves, East Matthew, New Hampshire...      Frank
# 1     1360 Tracey Ports Apt. 419, Kyleport, Vermont,...  Elizabeth
# 2     19120 Fleming Manors, Prestonstad, Montana, 23495     Donald
# 3          441 Olivia Creek, Jimmymouth, Georgia, 82991    Michael
# 4     4246 Chelsey Ford Apt. 310, Karamouth, Utah, 7...    Jasmine
# ...                                                 ...        ...
# 9956  762 Andrew Views Apt. 254, North Paul, New Mex...       Dana
# 9957  44188 Day Crest Apt. 901, Lake Marcia, Maine, ...     Amanda
# 9958  73015 Michelle Squares, Watsonville, West Virg...       Eric
# 9959       129 Keith Greens, Haleyfurt, Oklahoma, 98916     Taylor
# 9960   355 Griffin Valley, Davidtown, New Mexico, 17581     Sherry
#
#         Last Name
# 0         Manning
# 1         Johnson
# 2        Stephens
# 3     Vincent III
# 4          Zamora
# ...           ...
# 9956     Browning
# ...

# %%
customers[["Street", "City", "State", "Zip"]] = customers["Address"].str.split(pat=",", expand=True)

# %%
customers = customers.drop(labels=["Address"], axis="columns")

# %%
customers.head()
# Out:
#   First Name    Last Name                      Street           City  \
# 0      Frank      Manning           6461 Quinn Groves   East Matthew
# 1  Elizabeth      Johnson  1360 Tracey Ports Apt. 419       Kyleport
# 2     Donald     Stephens        19120 Fleming Manors    Prestonstad
# 3    Michael  Vincent III            441 Olivia Creek     Jimmymouth
# 4    Jasmine       Zamora  4246 Chelsey Ford Apt. 310      Karamouth
#
#             State     Zip
# 0   New Hampshire   16656
# 1         Vermont   31924
# 2         Montana   23495
# 3         Georgia   82991
# 4            Utah   76252

# %%
customers.set_index(keys="First Name")
# Out:
#               Last Name                      Street           City  \
# First Name
# Frank           Manning           6461 Quinn Groves   East Matthew
# Elizabeth       Johnson  1360 Tracey Ports Apt. 419       Kyleport
# Donald         Stephens        19120 Fleming Manors    Prestonstad
# Michael     Vincent III            441 Olivia Creek     Jimmymouth
# Jasmine          Zamora  4246 Chelsey Ford Apt. 310      Karamouth
# ...                 ...                         ...            ...
# Dana           Browning   762 Andrew Views Apt. 254     North Paul
# Amanda         Anderson    44188 Day Crest Apt. 901    Lake Marcia
# Eric              Davis      73015 Michelle Squares    Watsonville
# Taylor        Hernandez            129 Keith Greens      Haleyfurt
# Sherry        Nicholson          355 Griffin Valley      Davidtown
#
#                      State     Zip
# First Name
# Frank        New Hampshire   16656
# Elizabeth          Vermont   31924
# ...

# %%
customers.to_csv("datasets/new_customers.csv", index=False)
